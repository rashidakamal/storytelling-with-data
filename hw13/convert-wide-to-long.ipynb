# %%
import pandas as pd

# %%
df = pd.read_csv("internet_users.csv")

# %%
df.head()
# Out:
#   Country Name Country Code                   Indicator Name  Indicator Code  \
# 0        Aruba          ABW  Internet users (per 100 people)  IT.NET.USER.P2
# 1      Andorra          AND  Internet users (per 100 people)  IT.NET.USER.P2
# 2  Afghanistan          AFG  Internet users (per 100 people)  IT.NET.USER.P2
# 3       Angola          AGO  Internet users (per 100 people)  IT.NET.USER.P2
# 4      Albania          ALB  Internet users (per 100 people)  IT.NET.USER.P2
#
#    1960  1961  1962  1963  1964  1965  ...        2006       2007   2008  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...   28.000000  30.900000  52.00
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...   48.936847  70.870000  70.04
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...    2.107124   1.900000   1.84
# 3   NaN   NaN   NaN   NaN   NaN   NaN  ...    1.907648   3.200000   4.60
# 4   NaN   NaN   NaN   NaN   NaN   NaN  ...    9.609991  15.036115  23.86
#
#     2009  2010    2011       2012  2013   2014  2015
# ...

# %%
melted = pd.melt(df, id_vars=('Country Name','Country Code','Indicator Name','Indicator Code'), var_name='Year', value_name='Value')

# %%
melted.head()
# Out:
#   Country Name Country Code                   Indicator Name  Indicator Code  \
# 0        Aruba          ABW  Internet users (per 100 people)  IT.NET.USER.P2
# 1      Andorra          AND  Internet users (per 100 people)  IT.NET.USER.P2
# 2  Afghanistan          AFG  Internet users (per 100 people)  IT.NET.USER.P2
# 3       Angola          AGO  Internet users (per 100 people)  IT.NET.USER.P2
# 4      Albania          ALB  Internet users (per 100 people)  IT.NET.USER.P2
#
#    Year  Value
# 0  1960    NaN
# 1  1960    NaN
# 2  1960    NaN
# 3  1960    NaN
# 4  1960    NaN

# %%
melted.to_csv("melted.csv", index=False)
